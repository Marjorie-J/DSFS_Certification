# %% [markdown]
# # 04_Steam_Genres

# %% [markdown]
# ---

# %%
from pyspark.sql import functions as F
from pyspark.sql import Row

# %% [markdown]
# ### Chargement du dataset

# %%
df_steam_flat = spark.read.json("/dbfs/FileStore/export/steam_flat_prep.json")

# %% [markdown]
# ---

# %% [markdown]
# ### Analyse des genres

# %% [markdown]
# Quels sont les genres les plus représentés ?

# %%
df_steam_flat.select("genre").limit(5).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>genre</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Indie, Simulation, Strategy</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adventure, Free to Play, Indie</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Action, Adventure, Casual, Indie, Sports, Stra...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Action, Casual, Indie</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Adventure, Free to Play, Indie</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Les genres sont stockés comme une chaine de caractère, chacun séparé par une virgule.
#
# Je vais tout d'abord en faire une liste, puis j'explode cette colonne.

# %%
df_steam_genre = df_steam_flat \
  .withColumn("genre_list", F.split(F.col("genre"),",")) \
    .drop("genre")
df_steam_genre.select("genre_list").limit(5).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>genre_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[Indie,  Simulation,  Strategy]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[Adventure,  Free to Play,  Indie]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[Action,  Adventure,  Casual,  Indie,  Sports,...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[Action,  Casual,  Indie]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[Adventure,  Free to Play,  Indie]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_steam_genre_exploded = df_steam_genre.withColumn("genre", F.explode("genre_list"))
df_steam_genre_exploded.select("genre").limit(10).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>genre</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Indie</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Simulation</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Strategy</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Adventure</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Free to Play</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Indie</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Action</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Adventure</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Casual</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Indie</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
display(df_steam_genre_exploded.groupBy("genre").agg(F.countDistinct("appid").alias("nb_games")).orderBy(F.desc("nb_games")).limit(10).toPandas())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genre</th><th>nb_games</th></tr></thead><tbody><tr><td> Indie</td><td>34123</td></tr><tr><td>Action</td><td>23168</td></tr><tr><td> Casual</td><td>12238</td></tr><tr><td>Adventure</td><td>11100</td></tr><tr><td> Adventure</td><td>9961</td></tr><tr><td> Strategy</td><td>9851</td></tr><tr><td>Casual</td><td>9720</td></tr><tr><td> Simulation</td><td>9449</td></tr><tr><td> RPG</td><td>8539</td></tr><tr><td> Early Access</td><td>6060</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# Le genre le plus représenté est le genre **"Indie"** avec 34123 jeux, puis **"Action"** avec 23168 jeux.

# %% [markdown]
# ---

# %% [markdown]
# Existe-il des genres qui ont un meilleur rapport critiques positives/négatives ?

# %% [markdown]
# J'additionne les critiques positives et negatives par genre

# %%
df_genre_reviews = df_steam_genre_exploded.groupBy("genre").agg(
    F.sum("positive").alias("sum_positive"),
    F.sum("negative").alias("sum_negative"))

# %% [markdown]
# Je calcule du ratio global positif/négatif par genre

# %%
display(df_genre_reviews.withColumn("review_ratio", F.col("sum_positive") / F.col("sum_negative")).orderBy(F.desc("review_ratio")).limit(10).toPandas())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genre</th><th>sum_positive</th><th>sum_negative</th><th>review_ratio</th></tr></thead><tbody><tr><td> Photo Editing</td><td>572545</td><td>12430</td><td>46.061544650040226</td></tr><tr><td> Animation & Modeling</td><td>569505</td><td>12382</td><td>45.99458891939913</td></tr><tr><td> Design & Illustration</td><td>641338</td><td>18716</td><td>34.26683051934174</td></tr><tr><td> Utilities</td><td>659115</td><td>25808</td><td>25.539173899566027</td></tr><tr><td>Game Development</td><td>2335</td><td>119</td><td>19.6218487394958</td></tr><tr><td>Audio Production</td><td>53676</td><td>4196</td><td>12.792183031458531</td></tr><tr><td>Web Publishing</td><td>962</td><td>85</td><td>11.31764705882353</td></tr><tr><td>Indie</td><td>5445292</td><td>481604</td><td>11.306575526781339</td></tr><tr><td>Animation & Modeling</td><td>112426</td><td>11925</td><td>9.42775681341719</td></tr><tr><td> Video Production</td><td>101238</td><td>11556</td><td>8.760643821391485</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# Les genres qui ont le meilleur ratio critiques positives/négatives sont **Photo Editing** et **Animation & Modeling**

# %% [markdown]
# ---

# %% [markdown]
# Est-ce que certains éditeurs ont des genres favoris ?

# %% [markdown]
# Nombre de jeux par éditeur et par genre

# %%
df_pub_genre = df_steam_genre_exploded.groupBy("publisher", "genre").agg(F.count("appid").alias("nb_games"))

# %% [markdown]
# Nombre total de jeux par éditeur

# %%
df_pub_total = df_steam_genre_exploded.groupBy("publisher").agg(F.count("appid").alias("total_games"))

# %% [markdown]
# Calcul de la part de chaque genre chez l'éditeur

# %%
df_pub_pref = df_pub_genre.join(df_pub_total, on="publisher").withColumn("genre_share", F.col("nb_games") / F.col("total_games"))

# %% [markdown]
# On garde le genre le plus représenté chez un éditeur

# %%
from pyspark.sql import Window

window = Window.partitionBy("publisher").orderBy(F.desc("nb_games"))

display(df_pub_pref.withColumn("rank", F.row_number().over(window)).filter(F.col("rank") == 1).drop("rank").orderBy(F.desc("genre_share")).toPandas())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>publisher</th><th>genre</th><th>nb_games</th><th>total_games</th><th>genre_share</th></tr></thead><tbody><tr><td> Droid Riot</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td> Golden Dragon Studio</td><td>Casual</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td> Maciej Targoni</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td> Metal Fox</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td> RoBot </td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td> WhisperGames</td><td>Adventure</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>--</td><td>Casual</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>0o0</td><td>Audio Production</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>111144447777a</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>11PLANNING</td><td>RPG</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>1337 Game Design</td><td>Education</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>1C-SoftClub</td><td>Strategy</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>1SiGn Games</td><td>RPG</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>1bgame</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>2 Bit Determine</td><td>Indie</td><td>2</td><td>2</td><td>1.0</td></tr><tr><td>2&amp;30 Software</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>20 Watt Games</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>2054</td><td>Adventure</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>26horses</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>2D BOY </td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>2K, Feral Interactive (Linux)</td><td>Strategy</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>2MEDYA</td><td></td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>2S Games</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>3 Core Studio</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>3 Gentle Giants</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>3067 Games</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>3d Molier</td><td>Early Access</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>40 Pound Tiger</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>404.zero</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>42tones</td><td>Audio Production</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>4EversGames</td><td>Simulation</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>4PM GAME</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>5 Hours of Sleep</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>6502 Workshop</td><td>RPG</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>704 Games Company</td><td>Racing</td><td>3</td><td>3</td><td>1.0</td></tr><tr><td>717 pixels</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>8i</td><td>Adventure</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>A Game Studio</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>A Man and his Computer</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>A RanDom Fella</td><td>Casual</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>A.D. Klumpp</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>A3</td><td>Simulation</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>A9019</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>AA Games</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>ABG</td><td>Racing</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>AFL Productions</td><td>Video Production</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>AHMET ALP</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>ALEKSANDER CHEPAIKIN</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>ALLPlayer Group Ltd.</td><td>Utilities</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>ALPHA- ...

# %% [markdown]
# C'est assez difficile à dire car certains éditeurs sont très peu actifs et ont peu de jeux.
#
# L'éditeur **8floor** a principalement des jeux Casual : 79% de ses 243 jeux.
#
# L'éditeur **Big Fish Games** a principalement des jeux Adventure : 48% de ses 834 jeux.

# %% [markdown]
# ---

# %% [markdown]
# Quels sont les genres les plus lucratifs ?

# %% [markdown]
# J'étudie la colonne `discount`

# %%
from pyspark.sql.functions import min, max

df_steam_genre_exploded.select(min("discount").alias("min_discount"), max("discount").alias("max_discount")).show()
# Out:
# +------------+------------+
# |min_discount|max_discount|
# +------------+------------+
# |         0.0|        90.0|
# +------------+------------+

# %% [markdown]
# `discount` semble être un pourcentage.

# %% [markdown]
# J'étudie la colonne `owners`

# %%
df_steam_genre_exploded.select("owners").distinct().show()
# Out:
# +--------------------+
# |              owners|
# +--------------------+
# |  100,000 .. 200,000|
# |1,000,000 .. 2,00...|
# |20,000,000 .. 50,...|
# |5,000,000 .. 10,0...|
# |         0 .. 20,000|
# |    20,000 .. 50,000|
# |2,000,000 .. 5,00...|
# |50,000,000 .. 100...|
# |500,000 .. 1,000,000|
# |10,000,000 .. 20,...|
# |  200,000 .. 500,000|
# |   50,000 .. 100,000|
# |200,000,000 .. 50...|
# +--------------------+

# %% [markdown]
# `owners` est une plage de valeurs, je vais donc utiliser la moyenne pour mes calculs

# %%
from pyspark.sql.functions import split, translate

owners_clean = translate(F.col("owners"), ",", "")
split_owners = split(owners_clean, " .. ")

df_steam_genre_exploded = df_steam_genre_exploded \
       .withColumn("owners_min", split_owners.getItem(0)) \
       .withColumn("owners_max", split_owners.getItem(1)) \
       .withColumn("owners_avg", (F.col("owners_min") + F.col("owners_max")) / 2)

df_steam_genre_exploded.select("owners_avg").limit(5).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>owners_avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>150000.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>150000.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>150000.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10000.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10000.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Calcul du coût total : prix * nombre d'utilisateurs

# %%
df_steam_genre_exploded = df_steam_genre_exploded.withColumn("total_price", F.col("owners_avg") * F.col("price"))

df_steam_genre_exploded.select("total_price").limit(5).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>29850000.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>29850000.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>29850000.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Calcul du prix avec la remise

# %%
df_steam_genre_exploded = df_steam_genre_exploded.withColumn("discount_price", \
                    (100 - F.col("discount")) * F.col("total_price") / 100)

df_steam_genre_exploded.select("discount_price").limit(5).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>discount_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5970000.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5970000.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5970000.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Total des prix par genre

# %%
display(df_steam_genre_exploded.groupBy("genre").agg(F.sum("discount_price").alias("discount_price_sum")).orderBy(F.desc("discount_price_sum")).limit(10).toPandas())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genre</th><th>discount_price_sum</th></tr></thead><tbody><tr><td>Action</td><td>3.4115663809E12</td></tr><tr><td> Indie</td><td>2.2435447303E12</td></tr><tr><td> Adventure</td><td>1.64381710475E12</td></tr><tr><td> RPG</td><td>1.18136506835E12</td></tr><tr><td> Simulation</td><td>1.1517550709E12</td></tr><tr><td> Strategy</td><td>9.860631986E11</td></tr><tr><td>Adventure</td><td>7.2471420365E11</td></tr><tr><td>Indie</td><td>5.303221544E11</td></tr><tr><td> Early Access</td><td>4.834405423E11</td></tr><tr><td> Casual</td><td>4.320073469E11</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# Le genre **Action** est le plus lucratif, suivi de **Indie** et **Adventure**.
