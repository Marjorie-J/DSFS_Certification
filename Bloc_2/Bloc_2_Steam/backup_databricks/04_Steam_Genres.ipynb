# %% [markdown]
# # 04_Steam_Genres

# %% [markdown]
# ---

# %%
from pyspark.sql import functions as F
from pyspark.sql import Row

# %% [markdown]
# ### Chargement du dataset

# %%
df_steam_flat = spark.read.json("/dbfs/FileStore/export/steam_flat_prep.json")

# %% [markdown]
# ---

# %% [markdown]
# ### Analyse des genres

# %% [markdown]
# Quels sont les genres les plus représentés ?

# %%
df_steam_flat.select("genre").limit(5).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>genre</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Indie, Simulation, Strategy</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adventure, Free to Play, Indie</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Action, Adventure, Casual, Indie, Sports, Stra...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Action, Casual, Indie</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Adventure, Free to Play, Indie</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Les genres sont stockés comme une chaine de caractère, chacun séparé par une virgule.
#
# Je vais tout d'abord en faire une liste, puis j'explode cette colonne.

# %%
df_steam_genre = df_steam_flat \
  .withColumn("genre_list", F.split(F.col("genre"),",")) \
    .withColumn("genre_list", F.expr("transform(genre_list, x -> trim(x))")) \
    .drop("genre")
df_steam_genre.select("genre_list").limit(5).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>genre_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[Indie, Simulation, Strategy]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>[Adventure, Free to Play, Indie]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>[Action, Adventure, Casual, Indie, Sports, Str...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>[Action, Casual, Indie]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>[Adventure, Free to Play, Indie]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_steam_genre_exploded = df_steam_genre.withColumn("genre", F.explode("genre_list"))
display(df_steam_genre_exploded.select("genre").distinct().toPandas())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genre</th></tr></thead><tbody><tr><td>Education</td></tr><tr><td>Massively Multiplayer</td></tr><tr><td>Sexual Content</td></tr><tr><td>Adventure</td></tr><tr><td>Sports</td></tr><tr><td>Accounting</td></tr><tr><td>Audio Production</td></tr><tr><td>Video Production</td></tr><tr><td>Animation & Modeling</td></tr><tr><td>Racing</td></tr><tr><td>Gore</td></tr><tr><td>Design & Illustration</td></tr><tr><td>Software Training</td></tr><tr><td>Photo Editing</td></tr><tr><td>Web Publishing</td></tr><tr><td>Utilities</td></tr><tr><td>Violent</td></tr><tr><td>Game Development</td></tr><tr><td>Nudity</td></tr><tr><td>Early Access</td></tr><tr><td>Casual</td></tr><tr><td></td></tr><tr><td>Strategy</td></tr><tr><td>Action</td></tr><tr><td>Indie</td></tr><tr><td>Free to Play</td></tr><tr><td>RPG</td></tr><tr><td>Simulation</td></tr><tr><td>Movie</td></tr></tbody></table></div>

# %%
display(df_steam_genre_exploded.groupBy("genre").agg(F.countDistinct("appid").alias("nb_games")).orderBy(F.desc("nb_games")).limit(10).toPandas())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genre</th><th>nb_games</th></tr></thead><tbody><tr><td>Indie</td><td>39465</td></tr><tr><td>Action</td><td>23311</td></tr><tr><td>Casual</td><td>21958</td></tr><tr><td>Adventure</td><td>21061</td></tr><tr><td>Strategy</td><td>10654</td></tr><tr><td>Simulation</td><td>10532</td></tr><tr><td>RPG</td><td>9255</td></tr><tr><td>Early Access</td><td>6078</td></tr><tr><td>Free to Play</td><td>3391</td></tr><tr><td>Sports</td><td>2561</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# Les genres les plus représentés sur la plateforme sont **Indie**, avec 34 465 jeux, suivis par **Action**, **Casual** et **Adventure**, qui comptent chacun autour de 20 000 jeux.
#
# Les autres genres se situent en dessous de 10 000 jeux.

# %% [markdown]
# ---

# %% [markdown]
# Existe-il des genres qui ont un meilleur rapport critiques positives/négatives ?

# %% [markdown]
# J'additionne les critiques positives et negatives par genre

# %%
df_genre_reviews = df_steam_genre_exploded.groupBy("genre").agg(
    F.sum("positive").alias("sum_positive"),
    F.sum("negative").alias("sum_negative"))

# %% [markdown]
# Je calcule du ratio global positif/négatif par genre

# %%
display(df_genre_reviews.withColumn("review_ratio", F.col("sum_positive") / F.col("sum_negative")).orderBy(F.desc("review_ratio")).limit(10).toPandas())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genre</th><th>sum_positive</th><th>sum_negative</th><th>review_ratio</th></tr></thead><tbody><tr><td>Photo Editing</td><td>572664</td><td>12490</td><td>45.8497998398719</td></tr><tr><td>Animation & Modeling</td><td>681931</td><td>24307</td><td>28.05492245032295</td></tr><tr><td>Design & Illustration</td><td>657032</td><td>23658</td><td>27.772085552455827</td></tr><tr><td>Utilities</td><td>719255</td><td>40342</td><td>17.82893758365971</td></tr><tr><td>Audio Production</td><td>62815</td><td>5543</td><td>11.33231102291178</td></tr><tr><td>Game Development</td><td>25508</td><td>2851</td><td>8.947036127674501</td></tr><tr><td>Video Production</td><td>104481</td><td>12740</td><td>8.201020408163265</td></tr><tr><td>Indie</td><td>30495244</td><td>3920621</td><td>7.778166775110371</td></tr><tr><td></td><td>183740</td><td>25941</td><td>7.082996029451447</td></tr><tr><td>Casual</td><td>9691298</td><td>1385023</td><td>6.997210876642482</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# Le genre affichant le meilleur ratio critiques positives/négatives est **Photo Editing**, avec un score de 45.
# Il est suivi par **Animation & Modeling** et **Design & Illustration**, qui affichent un score de 28.
# Cela indique qu’ils reçoivent très peu de critiques négatives par rapport aux positives.
#
# Cependant, pour affiner cette analyse, il serait pertinent de confronter ce ratio au nombre total de critiques afin d’évaluer la robustesse des résultats.

# %% [markdown]
# ---

# %% [markdown]
# Est-ce que certains éditeurs ont des genres favoris ?

# %% [markdown]
# Nombre de jeux par éditeur et par genre

# %%
df_pub_genre = df_steam_genre_exploded.groupBy("publisher", "genre").agg(F.count("appid").alias("nb_games"))

# %% [markdown]
# Nombre total de jeux par éditeur

# %%
df_pub_total = df_steam_genre_exploded.groupBy("publisher").agg(F.count("appid").alias("total_games"))

# %% [markdown]
# Calcul de la part de chaque genre chez l'éditeur

# %%
df_pub_pref = df_pub_genre.join(df_pub_total, on="publisher").withColumn("genre_share", F.col("nb_games") / F.col("total_games"))

# %% [markdown]
# On garde le genre le plus représenté chez un éditeur

# %%
from pyspark.sql import Window

window = Window.partitionBy("publisher").orderBy(F.desc("nb_games"))

display(df_pub_pref.withColumn("rank", F.row_number().over(window)).filter(F.col("rank") == 1).drop("rank").orderBy(F.desc("genre_share")).toPandas())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>publisher</th><th>genre</th><th>nb_games</th><th>total_games</th><th>genre_share</th></tr></thead><tbody><tr><td> Metal Fox</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td> WhisperGames</td><td>Adventure</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>0o0</td><td>Audio Production</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>111144447777a</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>1SiGn Games</td><td>RPG</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>2 Bit Determine</td><td>Indie</td><td>2</td><td>2</td><td>1.0</td></tr><tr><td>20 Watt Games</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>2MEDYA</td><td></td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>3d Molier</td><td>Early Access</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>42tones</td><td>Audio Production</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>4EversGames</td><td>Simulation</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>5 Hours of Sleep</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>704 Games Company</td><td>Racing</td><td>3</td><td>3</td><td>1.0</td></tr><tr><td>AFL Productions</td><td>Video Production</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>ALEKSANDER CHEPAIKIN</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>ALLPlayer Group Ltd.</td><td>Utilities</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>ALPHA-NEXT</td><td>Adventure</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>AMTGames</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>AN GAMES Co.,Ltd</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Aardvark Studios</td><td>Casual</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Aaron D.</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Aaron Hunt</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Abstraction Games</td><td>Adventure</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Abyss Rift</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Acalamity</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Actawesome</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Active Up Games</td><td>Casual</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Actuator Games LLC</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Ada Rook</td><td>Adventure</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Adam Bond</td><td>Adventure</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Adelante LLC</td><td>Simulation</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Adriaan de Jongh, Sokpop Collective</td><td>Casual</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>AdventureFarmVR</td><td>Adventure</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Agaricus Games</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Aim Theory</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Akamaru Game</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Aldora Games</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>AlexGames</td><td></td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Alexander Casha</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Almighty Cow</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Ameshiko</td><td>Free to Play</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Ancient Empire Games LLC.</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Another Games</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Anvelopa</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Arctic Arcade</td><td>Sports</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Arctos Games</td><td>Action</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Areta Watanabe</td><td>Casual</td><td>1</td><td>1</td><td>1.0</td></tr><tr><td>Arevoatl Games</td><td>Indie</td><td>1</td><td>1</td><td>1.0</td></ ...

# %%
display(df_pub_pref.withColumn("rank", F.row_number().over(window)).filter(F.col("rank") == 1).drop("rank").filter(F.col("publisher").isin("8floor", "Big Fish Games")).orderBy(F.desc("genre_share")).toPandas())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>publisher</th><th>genre</th><th>nb_games</th><th>total_games</th><th>genre_share</th></tr></thead><tbody><tr><td>8floor</td><td>Casual</td><td>202</td><td>243</td><td>0.831275720164609</td></tr><tr><td>Big Fish Games</td><td>Casual</td><td>418</td><td>834</td><td>0.5011990407673861</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# Il est difficile de tirer des conclusions précises, car certains éditeurs sont peu actifs et disposent d’un catalogue restreint.
#
# Les éditeurs **8floor** et **Big Fish Games** se spécialisent principalement dans les jeux **Casual**, qui représentent respectivement 83 % et 50 % de leurs titres.
#
# Il convient toutefois de rester prudent, car certains jeux sont associés à plusieurs genres et seront donc comptabilisés autant de fois qu’ils ont de genres associés.

# %% [markdown]
# ---

# %% [markdown]
# Quels sont les genres les plus lucratifs ?

# %% [markdown]
# J'étudie la colonne `discount`

# %%
from pyspark.sql.functions import min, max

df_steam_genre_exploded.select(min("discount").alias("min_discount"), max("discount").alias("max_discount")).show()
# Out:
# +------------+------------+
# |min_discount|max_discount|
# +------------+------------+
# |         0.0|        90.0|
# +------------+------------+

# %% [markdown]
# `discount` semble être un pourcentage.

# %% [markdown]
# J'étudie la colonne `owners`

# %%
df_steam_genre_exploded.select("owners").distinct().show()
# Out:
# +--------------------+
# |              owners|
# +--------------------+
# |  100,000 .. 200,000|
# |1,000,000 .. 2,00...|
# |20,000,000 .. 50,...|
# |5,000,000 .. 10,0...|
# |         0 .. 20,000|
# |    20,000 .. 50,000|
# |2,000,000 .. 5,00...|
# |50,000,000 .. 100...|
# |500,000 .. 1,000,000|
# |10,000,000 .. 20,...|
# |  200,000 .. 500,000|
# |   50,000 .. 100,000|
# |200,000,000 .. 50...|
# +--------------------+

# %% [markdown]
# `owners` est une plage de valeurs, je vais donc utiliser la moyenne pour mes calculs

# %%
from pyspark.sql.functions import split, translate

owners_clean = translate(F.col("owners"), ",", "")
split_owners = split(owners_clean, " .. ")

df_steam_genre_exploded = df_steam_genre_exploded \
       .withColumn("owners_min", split_owners.getItem(0)) \
       .withColumn("owners_max", split_owners.getItem(1)) \
       .withColumn("owners_avg", (F.col("owners_min") + F.col("owners_max")) / 2)

df_steam_genre_exploded.select("owners_avg").limit(5).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>owners_avg</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>150000.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>150000.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>150000.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>10000.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>10000.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Calcul du coût total : prix * nombre d'utilisateurs

# %%
df_steam_genre_exploded = df_steam_genre_exploded.withColumn("total_price", F.col("owners_avg") * F.col("price"))

df_steam_genre_exploded.select("total_price").limit(5).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>29850000.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>29850000.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>29850000.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Calcul du prix avec la remise

# %%
df_steam_genre_exploded = df_steam_genre_exploded.withColumn("discount_price", \
                    (100 - F.col("discount")) * F.col("total_price") / 100)

df_steam_genre_exploded.select("discount_price").limit(5).toPandas()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>discount_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5970000.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5970000.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5970000.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Total des prix par genre

# %%
display(df_steam_genre_exploded.groupBy("genre").agg(F.sum("discount_price").alias("discount_price_sum")).orderBy(F.desc("discount_price_sum")).limit(10).toPandas())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>genre</th><th>discount_price_sum</th></tr></thead><tbody><tr><td>Action</td><td>3.4137965409E12</td></tr><tr><td>Indie</td><td>2.7738668847E12</td></tr><tr><td>Adventure</td><td>2.3685313084E12</td></tr><tr><td>RPG</td><td>1.36472824075E12</td></tr><tr><td>Simulation</td><td>1.3270737553E12</td></tr><tr><td>Strategy</td><td>1.245375694E12</td></tr><tr><td>Casual</td><td>6.845532868E11</td></tr><tr><td>Early Access</td><td>4.845338823E11</td></tr><tr><td>Massively Multiplayer</td><td>1.772861257E11</td></tr><tr><td>Racing</td><td>1.4545238335E11</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# Le genre **Action** est le plus lucratif, générant plus de 3 000 milliards de revenus.
# Il est suivi par les genres **Indie** et **Adventure**, qui enregistrent chacun environ 2 500 milliards de revenus.
#
# Ces trois genres dominent largement le marché par rapport aux autres.
