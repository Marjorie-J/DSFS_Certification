# %% [markdown]
# ## Lecture CSV

# %%
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

# %%
# Lecture du CSV
df_sd = pd.read_csv("../datas/SpeedDatingData.csv", encoding = "ISO-8859-1")
df_sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Columns: 195 entries, iid to amb5_3
# dtypes: float64(174), int64(13), object(8)
# memory usage: 12.5+ MB

# %%
df_sd.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 4      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## EDA

# %%
# Beaucoup de colonnes
pd.options.display.max_columns = None

# %%
df_sd.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %%
df_sd.describe(include="all")
# Out:
#                 iid           id       gender          idg       condtn  \
# count   8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean     283.675937     8.960248     0.500597    17.327166     1.828837
# std      158.583367     5.491329     0.500029    10.940735     0.376673
# min        1.000000     1.000000     0.000000     1.000000     1.000000
# 25%      154.000000     4.000000     0.000000     8.000000     2.000000
# 50%      281.000000     8.000000     1.000000    16.000000     2.000000
# 75%      407.000000    13.000000     1.000000    26.000000     2.000000
# max      552.000000    22.000000     1.000000    44.000000     2.000000
#
#                wave        round     position     positin1        order  \
# ...

# %%
df_sd.dtypes
# Out:
# iid           int64
# id          float64
# gender        int64
# idg           int64
# condtn        int64
#              ...
# attr5_3     float64
# sinc5_3     float64
# intel5_3    float64
# fun5_3      float64
# amb5_3      float64
# Length: 195, dtype: object

# %% [markdown]
# ### Analyse des participants : Qui sont-ils ?

# %% [markdown]
# Ages

# %%
fig = px.histogram(df_sd, x="age", labels={"age": "Âge"})
fig.update_layout(yaxis_title="Nombre d'individus", 
    title="Distribution des âges",
    title_x=0.5)
fig.show()

# %% [markdown]
# La distribution d'âge est-elle différente pour les hommes et les femmes ?

# %%
df_sd['gender_label'] = df_sd['gender'].map({0: 'Femme', 1: 'Homme'})

fig = px.histogram(df_sd, x="age", color="gender_label", labels={"gender_label": "Genre", "age": "Âge"})
fig.update_layout(yaxis_title="Nombre d'individus", 
    title="Distribution des âges par genre",
    title_x=0.5)
fig.show()

# %%
fig = px.box(df_sd, x="gender_label", y = "age", labels={"gender_label": "Genre", "age": "Âge"})
fig.update_layout(title="Distribution des âges par genre", title_x=0.5)
fig.show()

# %% [markdown]
# Pas de différence marquée d'âge entre genres. La population semble être composée en majorité de jeunes adultes (environ 22–30 ans).

# %% [markdown]
# Genre

# %%
df_gender = df_sd["gender_label"].value_counts().reset_index()
df_gender.head()
# Out:
#   gender_label  count
# 0        Homme   4194
# 1        Femme   4184

# %%
fig = px.bar(df_gender, x="gender_label", y="count", labels={"gender_label": "Genre"})
fig.update_layout(yaxis_title="Nombre d'individus", 
                  title="Répartition des genres", title_x=0.5)
fig.show()

# %% [markdown]
# Domaines d'études

# %%
df_field = df_sd["field_cd"].value_counts().reset_index()
display(df_field)
# Out:
#     field_cd  count
# 0        8.0   1925
# 1       10.0    993
# 2        5.0    864
# 3       13.0    709
# 4        3.0    696
# 5        1.0    665
# 6        9.0    626
# 7       11.0    468
# 8        6.0    325
# 9        7.0    241
# 10       2.0    207
# 11      15.0    187
# 12       4.0    143
# 13      14.0    126
# 14      18.0     52
# 15      16.0     40
# 16      12.0     19
# 17      17.0     10

# %%
df_field['field_cd_label'] = df_field['field_cd'].map({1: 'Law', 2: 'Math', 3: 'Social Science, Psychologist', 
                                                       4: 'Medical Science, Pharmaceuticals, and Bio Tech', 5: 'Engineering', 
                                                       6: 'English/Creative Writing/ Journalism', 7: 'History/Religion/Philosophy', 
                                                       8: 'Business/Econ/Finance', 9: 'Education, Academia', 10: 'Biological Sciences/Chemistry/Physics', 
                                                       11: 'Social Work', 12: 'Undergrad/undecided', 13: 'Political Science/International Affairs', 
                                                       14: 'Film', 15: 'Fine Arts/Arts Administration', 16: 'Languages', 
                                                       17: 'Architecture', 18: 'Other'})

# %%
fig = px.pie(df_field, names = "field_cd_label", values="count")
fig.update_layout(title="Répartition des domaines d'étude", title_x=0.5)
fig.show()

# %% [markdown]
# Carrière

# %%
df_career = df_sd["career_c"].value_counts().reset_index()
display(df_career)
# Out:
#     career_c  count
# 0        2.0   2320
# 1        7.0   2170
# 2        6.0    724
# 3        1.0    675
# 4        9.0    547
# 5        4.0    421
# 6       10.0    379
# 7        3.0    261
# 8        5.0    234
# 9       11.0    220
# 10      13.0     81
# 11      15.0     77
# 12      16.0     44
# 13       8.0     39
# 14      12.0     28
# 15      14.0     10
# 16      17.0     10

# %%
df_career['career_c_label'] = df_career['career_c'].map({1: 'Lawyer', 2: 'Academic/Research', 3: 'Psychologist', 
                                                       4: 'Doctor/Medicine', 5: 'Engineer', 
                                                       6: 'Creative Arts/Entertainment', 7: 'Banking/Consulting/Finance/Marketing/Business/CEO/Entrepreneur/Admin', 
                                                       8: 'Real Estate', 9: 'International/Humanitarian Affairs', 10: 'Undecided', 
                                                       11: 'Social Work', 12: 'Speech Pathology', 13: 'Politics', 
                                                       14: 'Pro sports/Athletics', 15: 'Other', 16: 'Journalism', 
                                                       17: 'Architecture'})

# %%
fig = px.pie(df_career, names = "career_c_label", values="count")
fig.update_layout(title="Répartition des carrières", title_x=0.5)
fig.show()

# %% [markdown]
# Races

# %%
df_race= df_sd["race"].value_counts().reset_index()
display(df_race)
# Out:
#    race  count
# 0   2.0   4727
# 1   4.0   1982
# 2   3.0    664
# 3   6.0    522
# 4   1.0    420

# %%
df_race['race_label'] = df_race['race'].map({1: 'Black/African American', 2: 'European/Caucasian-American', 3: 'Latino/Hispanic American', 
                                                       4: 'Asian/Pacific Islander/Asian-American', 5: 'Native American', 
                                                       6: 'Other'})

# %%
fig = px.pie(df_race, names = "race_label", values="count")
fig.update_layout(title="Répartition des races", title_x=0.5)
fig.show()

# %% [markdown]
# Quel est le but principal en participant à cet évenement ?

# %%
df_goal= df_sd["goal"].value_counts().reset_index()
display(df_goal)
# Out:
#    goal  count
# 0   1.0   3426
# 1   2.0   3012
# 2   3.0    631
# 3   5.0    510
# 4   6.0    419
# 5   4.0    301

# %%
df_goal['goal_label'] = df_goal['goal'].map({1: 'Seemed like a fun night out', 2: 'To meet new people', 3: 'To get a date', 
                                                       4: 'Looking for a serious relationship', 5: 'To say I did it', 
                                                       6: 'Other'})

# %%
fig = px.bar(df_goal, x="goal_label", y="count", labels={"goal_label": "But"})
fig.update_layout(title="Répartition des buts", title_x=0.5)
fig.show()

# %% [markdown]
# --------------------

# %% [markdown]
# ## Analyse

# %% [markdown]
# #### J'ai tout d'abord choisi d'explorer l'axe suivant : L'ordre des rendez-vous lors d'une soirée speed-dating influence-t-il la décision de revoir un partenaire ?

# %%
# Sélection des colonnes pertinentes pour l'analyse
columns_order_dec = [
    "dec",
    "order"
]

# Vérifier les valeurs manquantes
missing_values = df_sd[columns_order_dec].isnull().sum()
print(missing_values)
# Out:
# dec      0
# order    0
# dtype: int64

# %% [markdown]
# Le dataset est propre

# %%
# Moyenne des décisions de revoir le partenaire en fonction de l’ordre
order_dec = df_sd.groupby("order")["dec"].mean().reset_index()

fig = px.scatter(order_dec, x = "order", y = "dec", trendline = "ols")
# Modifier les noms des axes
fig.update_layout(xaxis_title="Ordre de passage", yaxis_title="Décision de revoir")

fig.show()

# %% [markdown]
# Observations :
#
# Les premiers rendez-vous montrent un taux de succès élevé (49.9%), mais cela semble être une valur à la marge.
#
# En effet les deux et troisièmes rendez-vous ont des taux de succès assez bas (39-42%), tout comme les derniers rendez-vous qui ont également un taux de succès bas (33-38%).
#
# Je n'observe donc rien de significatif, juste une *légère* baisse globale de la décision de revoir à mesure que la soirée avance.
#
# Je n'observe donc pas de correlation forte entre ces données.

# %% [markdown]
# -----------

# %% [markdown]
# #### Je choisi ensuite d'explorer les données sous l'axe suivant : A quels attributs les participants accordent-ils le plus d’importance dans la décision de revoir un partenaire ?

# %%
# Sélection des colonnes pertinentes pour l'analyse : décision de revoir le partenaire + évaluations (de 1 à 10) des partenaires sur la base de 6 attributs
columns_scorecard = [
    "dec",
    "attr",
    "sinc",
    "intel",
    "fun",
    "amb",
    "shar",
]

# Vérifier les valeurs manquantes
missing_values = df_sd[columns_scorecard].isnull().sum()
print(missing_values)
# Out:
# dec         0
# attr      202
# sinc      277
# intel     296
# fun       350
# amb       712
# shar     1067
# dtype: int64

# %% [markdown]
# Observations sur les valeurs manquantes :
# - dec : Aucune valeur manquante
# - attr contient des valeurs manquants : 2.4% du dataset
# - sinc contient des valeurs manquants : 3.3% du dataset
# - intel contient des valeurs manquants : 3.5% du dataset
# - fun contient des valeurs manquants : 4.1% du dataset
# - shar contient des valeurs manquants : 12.7% du dataset
#
# Je nettoye les données en supprimant les valeurs manquantes avant d'explorer les relations entre ces attributs et la décision de revoir le partenaire. ​

# %%
# Suppression des lignes avec des valeurs manquantes
df_sd_clean = df_sd[columns_scorecard].dropna()

# Vérifier que les valeurs manquantes ont été supprimées
df_sd_clean.isnull().sum()
# Out:
# dec      0
# attr     0
# sinc     0
# intel    0
# fun      0
# amb      0
# shar     0
# dtype: int64

# %% [markdown]
# Le dataset est propre

# %%
# On remplace la décision de revoir par "Oui" ou "Non", pour la visualisation
df_sd_clean["dec"] = df_sd_clean["dec"].apply(lambda x: "Oui" if x == 1 else "Non")
display(df_sd_clean)
# Out:
#       dec  attr  sinc  intel  fun  amb  shar
# 0     Oui   6.0   9.0    7.0  7.0  6.0   5.0
# 1     Oui   7.0   8.0    7.0  8.0  5.0   6.0
# 2     Oui   5.0   8.0    9.0  8.0  5.0   7.0
# 3     Oui   7.0   6.0    8.0  7.0  6.0   8.0
# 4     Oui   5.0   6.0    7.0  7.0  6.0   6.0
# ...   ...   ...   ...    ...  ...  ...   ...
# 8367  Non   2.0   7.0    6.0  6.0  6.0   7.0
# 8368  Non   3.0   4.0    6.0  4.0  4.0   4.0
# 8369  Non   3.0   3.0    9.0  6.0  9.0   6.0
# 8370  Non   2.0   7.0    9.0  8.0  7.0   8.0
# 8377  Non   3.0   7.0    6.0  4.0  8.0   1.0
#
# [7040 rows x 7 columns]

# %% [markdown]
# Nous allons analyser la moyenne de la notation de chaque attribut selon la décision de revoir

# %%
# Moyenne de la notation de chaque attribut selon la décision de revoir
df_mean = df_sd_clean.groupby("dec")[["attr", "sinc", "intel", "fun", "amb", "shar"]].mean().reset_index()
display(df_mean)
# Out:
#    dec      attr      sinc     intel       fun       amb      shar
# 0  Non  5.367757  6.848901  7.065684  5.695929  6.470529  4.713287
# 1  Oui  7.283235  7.580040  7.741436  7.325593  7.141469  6.452404

# %%
# on retravaille le dataframe pour avoir, pour chaque décision, l'attribut, la moyenne des notes pour cet attribut
melted_df = df_mean.melt(id_vars=["dec"], value_vars=["attr", "sinc", "intel", "fun", "amb", "shar"])
melted_df["variable"] = melted_df["variable"].apply(lambda x: "Attractivité" if x == "attr" 
                                                    else "Sincérité" if x == "sinc"
                                                    else "Intelligence" if x == "intel"
                                                    else "Humour" if x == "fun"
                                                    else "Ambition" if x == "amb"
                                                    else "Intérêts communs" if x == "shar" else "Aucun")
display(melted_df)
# Out:
#     dec          variable     value
# 0   Non      Attractivité  5.367757
# 1   Oui      Attractivité  7.283235
# 2   Non         Sincérité  6.848901
# 3   Oui         Sincérité  7.580040
# 4   Non      Intelligence  7.065684
# 5   Oui      Intelligence  7.741436
# 6   Non            Humour  5.695929
# 7   Oui            Humour  7.325593
# 8   Non          Ambition  6.470529
# 9   Oui          Ambition  7.141469
# 10  Non  Intérêts communs  4.713287
# 11  Oui  Intérêts communs  6.452404

# %%
#Visualisation des moyennes des notes des attributs selon la décision prise
fig = px.bar(melted_df, x="variable", y="value", color="dec", barmode="group", title="Moyenne des attributs selon la décision de revoir")
fig.update_layout(title_x=0.5, xaxis_title="Attributs",  yaxis_title="Valeur Moyenne", legend_title="Décision de revoir")

# %% [markdown]
# L'attractivité, l’humour et les intérêts communs ont des écarts plus marqués entre ceux qui sont souhaités être revus et ceux qui ne le sont pas.
#
# Cela pourrait indiquer que ces critères sont particulièrement importants dans la prise de décision contrairement à la sincérité, l'intelligence et l'ambition.
#
# Nous allons donc analyser plus précisémment la distribution des notes pour les 3 attributs : attractivité, humour et intérêts communs.

# %%
#Distribution des attributs Attractivité, Humour et Intérêts communs selon la décision

attributes = {"attr" : "Attractivité", "fun" : "Humour", "shar" : "Intérêts communs"}

# Création des subplots
fig = make_subplots(rows = 1, cols = 3, subplot_titles=[attributes[attr] for attr in attributes])

mask_oui = (df_sd_clean["dec"] == "Oui")
mask_non = (df_sd_clean["dec"] == "Non")

# Ajout des boxplots dans les subplots
for i, attr in enumerate(attributes):
    # Décision Oui
    fig.add_trace(
        go.Box(y=df_sd_clean[mask_oui][attr], name="Oui", marker_color="red"),
        row=1, col=i+1
    )
    # Décision Non
    fig.add_trace(
        go.Box(y=df_sd_clean[mask_non][attr], name="Non", marker_color="blue"),
        row=1, col=i+1
    )

fig.update_layout(title="Distribution des notes des attributs selon la décision", title_x=0.5, height=500, width=1200, showlegend=False)
fig.show()

# %% [markdown]
# Observations :
#
# 1. Attractivité
# "Oui" a une médiane plus élevée (7) que "Non" (5).
#
# L’étendue des scores "Oui" est plus concentrée (de 3 à 10, avec quelques valeurs aberrantes basses), tandis que "Non" s’étend plus largement (de 0 à 10).
#
# Les "Oui" semblent avoir une tendance générale à être jugés plus attractifs.
#
# 2. Humour
# Médianes assez proches : "Oui" 7, "Non" 6.
#
# Les valeurs extrêmes (outliers) apparaissent des deux côtés.
#
# 3. Intérêts communs
# Médiane plus élevée pour "Oui" (7) par rapport à "Non" (5).
#
# Le groupe "Non" a une étendue complète (0 à 10), alors que "Oui" est plus concentré entre environ 1 et 10.
#
# Peu ou pas d’outliers visibles ici.
#
# Interprétation générale :
#
# Pour Attractivité et Intérêts communs, le groupe "Oui" tend à avoir des valeurs plus élevées et plus concentrées.
#
# Pour Humour, la différence est moins marquée mais "Oui" reste un peu au-dessus en médiane.
#
# Les outliers sont plus fréquents dans le groupe "Non", ce qui peut indiquer plus de variabilité dans les notes données à ce groupe.
#
#
#
#
# - Peu d'outliers (valeurs extrêmes). Peu de personnes ont reçu des notes très différentes de la majorité
# - Distribution (étendue des moustaches et taille des boîtes) :
#     - Distribution large : Les notes sont plus dispersées, ce qui signifie que les avis sont plus partagés. J'en déduis qu'il y a moins de consensus parmi les participants sur l’importance de cet attribut. Ce qui est le cas pour les décisions par rapport aux intérêts communs et la boîte "Non" de l'attractivité.
#     - Distribution resserrée : Les notes sont plus concentrées autour de la médiane. J'en déduis que la plupart des décisions sont assez cohérentes et suivent un schéma clair. Par exemple, une forte attractivité est souvent associée à un "Oui", comme pour l'humour.
# - Quartiles :
#     - Q1 et Q3 relativement rapprochés (Exemple pour les "Oui" de l’attractivité et l’humour), cela montre que la majorité des notes reste élevée
#     - Q1 plus petit que Q3 (et boite plus grande, exemple les "Non" de l'Intérêt commun), cela rejoint la conclusion de la distribution large : Les notes sont plus dispersées et montrent moins de cohérence dans la prise de décision.

# %% [markdown]
# L’attractivité joue un rôle important dans la décision de revoir quelqu’un. Ceux qui ont une note basse sont rarement revus.
#
# L'humour semble également important, avec toutefois une différence entre "Oui" et "Non qui semble moins marquée que pour l'attractivité.
#
# Concernant les intérêts communs, les notes sont plus dispersées. Cet attribut semble montrer moins de cohérence dans la prise de décision.

# %% [markdown]
# ------

# %% [markdown]
# ###  Quels sont les attributs les moins désirables chez un partenaire masculin ? Est-ce différents pour les partenaires féminines ?

# %% [markdown]
# POURQUOI ??????

# %%
# Séparer les vagues selon le système de notation
waves_6_9 = df_sd[(df_sd['wave'] >= 6) & (df_sd['wave'] <= 9)]
waves_other = df_sd[(df_sd['wave'] <= 5) | (df_sd['wave'] >= 10)]

# %%
attributes = ["attr1_1", "sinc1_1", "intel1_1", "fun1_1", "amb1_1", "shar1_1"]

# %%
# --- Analyse pour waves 6-9 (notes 1-10) ---
mean_attr_6_9 = waves_6_9.groupby('gender_label')[attributes].mean()

# %%
mean_attr_6_9.rename(columns={
    'attr1_1': 'Attractivité',
    'sinc1_1': 'Sincérité',
    'intel1_1': 'Intelligence',
    'fun1_1': 'Humour',
    'amb1_1': 'Ambition',
    'shar1_1': 'Intérêts communs'
}, inplace=True)

# %%
# --- Analyse pour waves 1-5 & 10-21 (répartition 100 points) ---
mean_attr_other = waves_other.groupby('gender_label')[attributes].mean()

# %%
mean_attr_other.rename(columns={
    'attr1_1': 'Attractivité',
    'sinc1_1': 'Sincérité',
    'intel1_1': 'Intelligence',
    'fun1_1': 'Humour',
    'amb1_1': 'Ambition',
    'shar1_1': 'Intérêts communs'
}, inplace=True)

# %%
# HOMMES

top3_homme_6_9 = (
    mean_attr_6_9.loc['Homme']
    .sort_values()
    .head(3)
    .reset_index()
    .rename(columns={'index': 'attribute', 'Homme': 'importance'})
)
top3_homme_6_9['method'] = 'Waves 6–9 : Échelle 1–10'

top3_homme_other = (
    mean_attr_other.loc['Homme']
    .sort_values()
    .head(3)
    .reset_index()
    .rename(columns={'index': 'attribute', 'Homme': 'importance'})
)
top3_homme_other['method'] = 'Waves 1–5 & 10–21 : 100 points'

top3_homme_combined = pd.concat([top3_homme_6_9, top3_homme_other])

# %%
# FEMMES

top3_femme_6_9 = (
    mean_attr_6_9.loc['Femme']
    .sort_values()
    .head(3)
    .reset_index()
    .rename(columns={'index': 'attribute', 'Femme': 'importance'})
)
top3_femme_6_9['method'] = 'Waves 6–9 : Échelle 1–10'

top3_femme_other = (
    mean_attr_other.loc['Femme']
    .sort_values()
    .head(3)
    .reset_index()
    .rename(columns={'index': 'attribute', 'Femme': 'importance'})
)
top3_femme_other['method'] = 'Waves 1–5 & 10–21 : 100 points'

top3_femme_combined = pd.concat([top3_femme_6_9, top3_femme_other])

# %%
# Créer les subplots (2 ligne, 2 colonnes)
fig = make_subplots(
    rows=2, cols=2,
    subplot_titles=(
        "Hommes",
        "Femmes"
    )
)

# Hommes : Waves 6-9
fig.add_trace(
    go.Bar(
        x=top3_homme_6_9['attribute'],
        y=top3_homme_6_9['importance'],
        name="Homme",
        marker_color='steelblue',
        text=top3_homme_6_9['importance'].round(2)
    ),
    row=1, col=1
)

# Hommes : Waves Autres
fig.add_trace(
    go.Bar(
        x=top3_homme_other['attribute'],
        y=top3_homme_other['importance'],
        name="Homme",
        marker_color='steelblue',
        text=top3_homme_other['importance'].round(2)
    ),
    row=2, col=1
)

# Femmes : Waves 6-9
fig.add_trace(
    go.Bar(
        x=top3_femme_6_9['attribute'],
        y=top3_femme_6_9['importance'],
        name="Homme",
        marker_color='indianred',
        text=top3_femme_6_9['importance'].round(2)
    ),
    row=1, col=2
)

# Femmes : Waves Autres
fig.add_trace(
    go.Bar(
        x=top3_femme_other['attribute'],
        y=top3_femme_other['importance'],
        name="Homme",
        marker_color='indianred',
        text=top3_femme_other['importance'].round(2)
    ),
    row=2, col=2
)

# Layout final
fig.update_layout(
    title_text="Top 3 attributs les moins désirables, par genre, par système de notation", 
    showlegend=False
)
fig.update_yaxes(title_text="Waves 6-9", row=1)
fig.update_yaxes(title_text="Waves 1-5, 10-21", row=2)
fig.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Partager des intérêts communs, est-ce plus important que de paratger une origine éthnique ?

# %%
df_sd["int_corr"].value_counts()
# Out:
# int_corr
#  0.31    140
#  0.13    124
#  0.24    116
#  0.19    112
#  0.11    112
#         ...
#  0.91      2
#  0.84      2
# -0.64      2
# -0.73      2
# -0.54      2
# Name: count, Length: 155, dtype: int64

# %% [markdown]
#  Cela donne un coefficient entre -1 et 1 :
#
# +1 : intérêts parfaitement alignés.
#
# 0 : pas de lien.
#
# -1 : intérêts opposés.

# %%
df_sd['match_label'] = df_sd['match'].map({0: 'Non', 1: 'Oui'})

# %%
fig = px.box(df_sd, x='match_label', y='int_corr',
             title="Corrélation des intérêts selon le match",
             labels={"match": "Match", "int_corr": "Corrélation des intérêts"})
fig.show()

# %%
df_grouped = df_sd.groupby('match_label')['samerace'].mean().reset_index()
df_grouped['samerace'] *= 100  # pourcentages

fig = px.bar(df_grouped, x='match_label', y='samerace',
             title="Pourcentage de paires de même origine ethnique selon match",
             labels={"match": "Match", "samerace": "Pourcentage même origine ethnique"})
fig.show()

# %%
corr_matrix = df_sd[['int_corr', 'samerace', 'match']].corr()
fig = ff.create_annotated_heatmap(
    z=corr_matrix.values,
    x=list(corr_matrix.columns),
    y=list(corr_matrix.index),
    annotation_text=[[f"{v:.2f}" for v in row] for row in corr_matrix.values],
    showscale=True,
    colorscale="Viridis"
)
fig.update_layout(title="Matrice de corrélation")
fig.show()

# %% [markdown]
# Pour conclure :
#
# A la question "L'équipe marketing constate une diminution du nombre de matchs et essaie de trouver un moyen de comprendre ce qui motive les gens à s'intéresser les uns aux autres"
#
# Nous pouvons répondre que l'ATTRACTIVITE, l'HUMOUR et les INTERETS COMMUNS sont des facteurs déterminants.
